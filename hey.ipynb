# %% [markdown]
# <a href="https://colab.research.google.com/github/ja616/nn_simulator/blob/master/hey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ja616/nn_simulator
# Out:
# Cloning into 'nn_simulator'...
# remote: Enumerating objects: 1251, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 1251 (delta 5), reused 10 (delta 3), pack-reused 1236 (from 1)
# Receiving objects: 100% (1251/1251), 1.73 MiB | 4.71 MiB/s, done.
# Resolving deltas: 100% (776/776), done.

# %%
# %cd /content/nn_simulator
# !pip install --upgrade pip setuptools wheel
# !pip install numpy matplotlib networkx more-itertools
# !pip install -r requirements.txt
# Out:
# /content/nn_simulator
# ...
#   Using cached build-0.10.0-py3-none-any.whl.metadata (4.1 kB)
# ERROR: Ignored the following yanked versions: 13.5.0
# ERROR: Could not find a version that satisfies the requirement cupy-cuda12x==12.0.0 (from versions: 12.3.0, 13.0.0, 13.1.0, 13.2.0, 13.3.0, 13.4.0, 13.4.1, 13.5.1, 13.6.0)
# ERROR: No matching distribution found for cupy-cuda12x==12.0.0

# %%
pip install -e .
# Out:
# Obtaining file:///content/nn_simulator
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for nn_simulator (pyproject.toml) ... done
#   Created wheel for nn_simulator: filename=nn_simulator-2.0.0-0.editable-py3-none-any.whl size=2934 sha256=0fc04fdea8b38d56c45baecdb551ba2222f5ec4dd4ba6480eb83a7835b1e7ed9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sys3854g/wheels/dd/fe/73/1d6d6f4d7a5c5c015a6d0309561186762028a5beb8125fd3f2
# Successfully built nn_simulator
# ...

# %%
import nn_simulator
help(nn_simulator)
# Out:
# Help on package nn_simulator:
#
# NAME
#     nn_simulator
#
# PACKAGE CONTENTS
#     nn_simulator (package)
#     test (package)
#
# FILE
#     /content/nn_simulator/__init__.py

# %%
# %cd /content/nn_simulator/example
# !python simulation.py
# Out:
# /content/nn_simulator/example
# [2025-11-04 01:38:11,896 INFO]	 Generating network data
# [2025-11-04 01:38:25,571 INFO]	 Saving graph to file
# /usr/local/lib/python3.12/dist-packages/networkx/readwrite/json_graph/node_link.py:145: FutureWarning:
# The default value will be `edges="edges" in NetworkX 3.6.
#
# To make this warning go away, explicitly set the edges kwarg, e.g.:
#
#   nx.node_link_data(G, edges="links") to preserve current behavior, or
#   nx.node_link_data(G, edges="edges") for forward compatibility.
#   warnings.warn(
# [2025-11-04 01:38:32,172 INFO]	 Electrical stimulation of the network
# 100% (90 of 90) |########################| Elapsed Time: 0:00:08 Time:  0:00:08

# %%
# %cd /content/nn_simulator
# !pip install -e .
# Out:
# [Errno 2] No such file or directory: '/content/nn_simulator'
# /content
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
from nn_simulator.controller import backup

graph, default, wires_dict, _ = backup.read()
print("Number of nodes (wires):", len(graph.nodes()))
print("Number of edges (junctions):", len(graph.edges()))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1124932749.py in <cell line: 0>()
# ----> 1 from nn_simulator.controller import backup
#       2
#       3 graph, default, wires_dict, _ = backup.read()
#       4 print("Number of nodes (wires):", len(graph.nodes()))
#       5 print("Number of edges (junctions):", len(graph.edges()))
#
# ModuleNotFoundError: No module named 'nn_simulator.controller'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# %cd /content/nn_simulator
# !git config --global user.email "aishwaryajacse@gmail.com"
# !git config --global user.name "ja616"
# !git add .
# !git commit -m "1st commit"
# Out:
# /content/nn_simulator
# [master b8dbc73] 1st commit
#  3 files changed, 7 insertions(+), 9 deletions(-)

# %%
# %cd /content/nn_simulator
# !git remote set-url origin https://<USERNAME>:<TOKEN>@github.com/<USERNAME>/nn_simulator.git

# !git push origin master
# Out:
# /content/nn_simulator
# fatal: could not read Username for 'https://github.com': No such device or address
